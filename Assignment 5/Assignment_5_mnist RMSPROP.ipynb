# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from statistics import mean

# %%
# X_train = pd.read_csv("/content/drive/MyDrive/CSULB Assignments/CECS 551 ADV AI/Assignment 5/mnist/train-images-idx3-ubyte")

# %%
from keras.datasets import mnist

# %%
# from mnist import MNIST
import os
import numpy as np

(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
np.shape(train_X)
# Out:
# (60000, 28, 28)

# %%
np.shape(test_X)
# Out:
# (10000, 28, 28)

# %%
import matplotlib.pyplot as plt
import numpy as np

id = 7

image = np.array(train_X[id], dtype='float')
pixels = image.reshape((28, 28))
plt.imshow(pixels, cmap='gray')
plt.show()

# print(X_train[id])
print(train_y[id])
# Out:
# 3

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation, Dropout
from keras.optimizers import Adam ,RMSprop
from keras import  backend as K

# %%
#unique train labels
unique, counts = np.unique(train_y, return_counts=True)
print("Train labels: ", dict(zip(unique, counts)))

#unique test labels
unique, counts = np.unique(test_y, return_counts=True)
print("\nTest labels: ", dict(zip(unique, counts)))
# Out:
# Train labels:  {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
#
# Test labels:  {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
n_labels = len(np.unique(train_y))
n_labels
# Out:
# 10

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.utils import to_categorical, plot_model

# %%
#one-hot vector
train_y = to_categorical(train_y)
test_y = to_categorical(test_y)

# %%
img_size = train_X.shape[1]
input_size = img_size * img_size
input_size
# Out:
# 784

# %%
train_X = np.reshape(train_X, [-1, input_size])
train_X = train_X.astype('float32') / 255
test_X = np.reshape(test_X, [-1, input_size])
test_X = test_X.astype('float32') / 255

# %%
np.shape(test_X)
# Out:
# (10000, 784)

# %%
from sklearn.model_selection import train_test_split

x_subtrain1, x_valid1, y_subtrain1, y_valid1 = train_test_split(train_X, train_y, test_size=0.16, random_state=1)
x_subtrain2, x_valid2, y_subtrain2, y_valid2 = train_test_split(train_X, train_y, test_size=0.16, random_state=2)
x_subtrain3, x_valid3, y_subtrain3, y_valid3 = train_test_split(train_X, train_y, test_size=0.16, random_state=3)
x_subtrain4, x_valid4, y_subtrain4, y_valid4 = train_test_split(train_X, train_y, test_size=0.16, random_state=4)
x_subtrain5, x_valid5, y_subtrain5, y_valid5 = train_test_split(train_X, train_y, test_size=0.16, random_state=5)
x_subtrain6, x_valid6, y_subtrain6, y_valid6 = train_test_split(train_X, train_y, test_size=0.16, random_state=6)
x_subtrain7, x_valid7, y_subtrain7, y_valid7 = train_test_split(train_X, train_y, test_size=0.16, random_state=7)
x_subtrain8, x_valid8, y_subtrain8, y_valid8 = train_test_split(train_X, train_y, test_size=0.16, random_state=8)
x_subtrain9, x_valid9, y_subtrain9, y_valid9 = train_test_split(train_X, train_y, test_size=0.16, random_state=9)
x_subtrain10, x_valid10, y_subtrain10, y_valid10 = train_test_split(train_X, train_y, test_size=0.16, random_state=10)

# %% [markdown]
# #RMSProp Optimizer

# %%
from keras.layers import Dense
from tensorflow.keras.optimizers import Adagrad
import tensorflow as tf
tf.keras.optimizers.RMSprop(learning_rate=0.01, rho=0.8, momentum=0.9, epsilon=1e-08, centered=False, name="RMSprop")

model = Sequential()
model.add(Dense(32, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(n_labels))
model.add(Activation('softmax'))

model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(x_subtrain10, y_subtrain10, epochs=60, batch_size=64)
# Out:
# Epoch 1/60
# 788/788 [==============================] - 3s 3ms/step - loss: 0.6252 - accuracy: 0.8134
# Epoch 2/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.3713 - accuracy: 0.8901
# Epoch 3/60
# 788/788 [==============================] - 3s 4ms/step - loss: 0.3268 - accuracy: 0.9021
# Epoch 4/60
# 788/788 [==============================] - 3s 4ms/step - loss: 0.3031 - accuracy: 0.9114
# Epoch 5/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2916 - accuracy: 0.9145
# Epoch 6/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2785 - accuracy: 0.9179
# Epoch 7/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2704 - accuracy: 0.9204
# Epoch 8/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2650 - accuracy: 0.9221
# Epoch 9/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2587 - accuracy: 0.9243
# Epoch 10/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2503 - accuracy: 0.9262
# Epoch 11/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2512 - accuracy: 0.9279
# Epoch 12/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2528 - accuracy: 0.9280
# Epoch 13/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2439 - accuracy: 0.9298
# Epoch 14/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2466 - accuracy: 0.9294
# Epoch 15/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2402 - accuracy: 0.9309
# Epoch 16/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2410 - accuracy: 0.9321
# Epoch 17/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2373 - accuracy: 0.9334
# Epoch 18/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2354 - accuracy: 0.9329
# Epoch 19/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2365 - accuracy: 0.9328
# Epoch 20/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2346 - accuracy: 0.9335
# Epoch 21/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2391 - accuracy: 0.9324
# Epoch 22/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2333 - accuracy: 0.9352
# Epoch 23/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2331 - accuracy: 0.9344
# Epoch 24/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2329 - accuracy: 0.9352
# Epoch 25/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2259 - accuracy: 0.9364
# Epoch 26/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2251 - accuracy: 0.9360
# Epoch 27/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2322 - accuracy: 0.9347
# Epoch 28/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2322 - accuracy: 0.9371
# Epoch 29/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2303 - accuracy: 0.9356
# Epoch 30/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2314 - accuracy: 0.9358
# Epoch 31/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2266 - accuracy: 0.9392
# Epoch 32/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2268 - accuracy: 0.9367
# Epoch 33/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2244 - accuracy: 0.9389
# Epoch 34/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2244 - accuracy: 0.9386
# Epoch 35/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2245 - accuracy: 0.9380
# Epoch 36/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2291 - accuracy: 0.9373
# Epoch 37/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2236 - accuracy: 0.9371
# Epoch 38/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2294 - accuracy: 0.9386
# Epoch 39/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2265 - accuracy: 0.9391
# Epoch 40/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2247 - accuracy: 0.9373
# Epoch 41/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2230 - accuracy: 0.9390
# Epoch 42/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2238 - accuracy: 0.9385
# Epoch 43/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2271 - accuracy: 0.9387
# Epoch 44/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2232 - accuracy: 0.9400
# Epoch 45/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2275 - accuracy: 0.9374
# Epoch 46/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2296 - accuracy: 0.9381
# Epoch 47/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2247 - accuracy: 0.9372
# Epoch 48/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2255 - accuracy: 0.9385
# Epoch 49/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2203 - accuracy: 0.9393
# Epoch 50/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2307 - accuracy: 0.9374
# Epoch 51/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2246 - accuracy: 0.9392
# Epoch 52/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2256 - accuracy: 0.9391
# Epoch 53/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2297 - accuracy: 0.9382
# Epoch 54/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2262 - accuracy: 0.9382
# Epoch 55/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2274 - accuracy: 0.9368
# Epoch 56/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2213 - accuracy: 0.9394
# Epoch 57/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2287 - accuracy: 0.9391
# Epoch 58/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.2298 - accuracy: 0.9390
# Epoch 59/60
# 788/788 [==============================] - 3s 3ms/step - loss: 0.2296 - accuracy: 0.9388
# Epoch 60/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.2280 - accuracy: 0.9393

# %%
train_acc = hist.history['accuracy']

# %%
avg_train = mean(train_acc)
print(avg_train*100)
# Out:
# 93.09656083583832

# %% [markdown]
# #Evaluation on Validation Set

# %%
_, accuracy = model.evaluate(x_valid10, y_valid10)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 300/300 [==============================] - 1s 2ms/step - loss: 0.2340 - accuracy: 0.9550
# Accuracy: 95.50

# %% [markdown]
# #Training with best Hyper-parameters -  ((0.01,0.3, 0.5,1e-08))

# %%
tf.keras.optimizers.RMSprop(learning_rate=0.01, rho=0.8, momentum=0.9, epsilon=1e-08, centered=False, name="RMSprop")

model = Sequential()
model.add(Dense(32, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(n_labels))
model.add(Activation('softmax'))

model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_X, train_y, epochs=60, batch_size=64)
# Out:
# Epoch 1/60
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6877 - accuracy: 0.7906
# Epoch 2/60
# 938/938 [==============================] - 3s 4ms/step - loss: 0.4486 - accuracy: 0.8657
# Epoch 3/60
# 938/938 [==============================] - 3s 4ms/step - loss: 0.4084 - accuracy: 0.8768
# Epoch 4/60
# 938/938 [==============================] - 3s 4ms/step - loss: 0.3805 - accuracy: 0.8846
# Epoch 5/60
# 938/938 [==============================] - 4s 4ms/step - loss: 0.3673 - accuracy: 0.8894
# Epoch 6/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3626 - accuracy: 0.8929
# Epoch 7/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3524 - accuracy: 0.8950
# Epoch 8/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3454 - accuracy: 0.8967
# Epoch 9/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3442 - accuracy: 0.8982
# Epoch 10/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3434 - accuracy: 0.8985
# Epoch 11/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3417 - accuracy: 0.9001
# Epoch 12/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3374 - accuracy: 0.9018
# Epoch 13/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3350 - accuracy: 0.9032
# Epoch 14/60
# 938/938 [==============================] - 4s 4ms/step - loss: 0.3311 - accuracy: 0.9033
# Epoch 15/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3307 - accuracy: 0.9062
# Epoch 16/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3271 - accuracy: 0.9057
# Epoch 17/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3272 - accuracy: 0.9073
# Epoch 18/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3292 - accuracy: 0.9068
# Epoch 19/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3263 - accuracy: 0.9074
# Epoch 20/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3321 - accuracy: 0.9070
# Epoch 21/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3335 - accuracy: 0.9061
# Epoch 22/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3297 - accuracy: 0.9086
# Epoch 23/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3261 - accuracy: 0.9076
# Epoch 24/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3339 - accuracy: 0.9071
# Epoch 25/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3319 - accuracy: 0.9061
# Epoch 26/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3264 - accuracy: 0.9090
# Epoch 27/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3329 - accuracy: 0.9078
# Epoch 28/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3256 - accuracy: 0.9081
# Epoch 29/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3338 - accuracy: 0.9067
# Epoch 30/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3299 - accuracy: 0.9089
# Epoch 31/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3342 - accuracy: 0.9082
# Epoch 32/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3240 - accuracy: 0.9105
# Epoch 33/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3320 - accuracy: 0.9097
# Epoch 34/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3382 - accuracy: 0.9082
# Epoch 35/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3338 - accuracy: 0.9087
# Epoch 36/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3334 - accuracy: 0.9103
# Epoch 37/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3371 - accuracy: 0.9072
# Epoch 38/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3348 - accuracy: 0.9092
# Epoch 39/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3340 - accuracy: 0.9092
# Epoch 40/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3323 - accuracy: 0.9104
# Epoch 41/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3418 - accuracy: 0.9104
# Epoch 42/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3328 - accuracy: 0.9110
# Epoch 43/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3400 - accuracy: 0.9105
# Epoch 44/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3362 - accuracy: 0.9104
# Epoch 45/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3394 - accuracy: 0.9092
# Epoch 46/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3373 - accuracy: 0.9095
# Epoch 47/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3423 - accuracy: 0.9101
# Epoch 48/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3413 - accuracy: 0.9105
# Epoch 49/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3430 - accuracy: 0.9086
# Epoch 50/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3355 - accuracy: 0.9096
# Epoch 51/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3412 - accuracy: 0.9097
# Epoch 52/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3424 - accuracy: 0.9107
# Epoch 53/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3403 - accuracy: 0.9105
# Epoch 54/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3368 - accuracy: 0.9095
# Epoch 55/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3383 - accuracy: 0.9122
# Epoch 56/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3448 - accuracy: 0.9089
# Epoch 57/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3436 - accuracy: 0.9105
# Epoch 58/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.3469 - accuracy: 0.9098
# Epoch 59/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3408 - accuracy: 0.9093
# Epoch 60/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3491 - accuracy: 0.9094

# %%
model.evaluate(test_X, test_y)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2394 - accuracy: 0.9537
# [0.23943208158016205, 0.9537000060081482]
