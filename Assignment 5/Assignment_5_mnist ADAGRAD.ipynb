# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from statistics import mean

# %%
# X_train = pd.read_csv("/content/drive/MyDrive/CSULB Assignments/CECS 551 ADV AI/Assignment 5/mnist/train-images-idx3-ubyte")

# %%
from keras.datasets import mnist

# %%
# from mnist import MNIST
import os
import numpy as np

(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %%
np.shape(train_X)
# Out:
# (60000, 28, 28)

# %%
np.shape(test_X)
# Out:
# (10000, 28, 28)

# %%
import matplotlib.pyplot as plt
import numpy as np

id = 7

image = np.array(train_X[id], dtype='float')
pixels = image.reshape((28, 28))
plt.imshow(pixels, cmap='gray')
plt.show()

# print(X_train[id])
print(train_y[id])
# Out:
# 3

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation, Dropout
from keras.optimizers import Adam ,RMSprop
from keras import  backend as K

# %%
#unique train labels
unique, counts = np.unique(train_y, return_counts=True)
print("Train labels: ", dict(zip(unique, counts)))

#unique test labels
unique, counts = np.unique(test_y, return_counts=True)
print("\nTest labels: ", dict(zip(unique, counts)))
# Out:
# Train labels:  {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
#
# Test labels:  {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
n_labels = len(np.unique(train_y))
n_labels
# Out:
# 10

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.utils import to_categorical, plot_model

# %%
#one-hot vector
train_y = to_categorical(train_y)
test_y = to_categorical(test_y)

# %%
img_size = train_X.shape[1]
input_size = img_size * img_size
input_size
# Out:
# 784

# %%
train_X = np.reshape(train_X, [-1, input_size])
train_X = train_X.astype('float32') / 255
test_X = np.reshape(test_X, [-1, input_size])
test_X = test_X.astype('float32') / 255

# %%
np.shape(test_X)
# Out:
# (10000, 784)

# %%
from sklearn.model_selection import train_test_split

x_subtrain1, x_valid1, y_subtrain1, y_valid1 = train_test_split(train_X, train_y, test_size=0.16, random_state=1)
x_subtrain2, x_valid2, y_subtrain2, y_valid2 = train_test_split(train_X, train_y, test_size=0.16, random_state=2)
x_subtrain3, x_valid3, y_subtrain3, y_valid3 = train_test_split(train_X, train_y, test_size=0.16, random_state=3)
x_subtrain4, x_valid4, y_subtrain4, y_valid4 = train_test_split(train_X, train_y, test_size=0.16, random_state=4)
x_subtrain5, x_valid5, y_subtrain5, y_valid5 = train_test_split(train_X, train_y, test_size=0.16, random_state=5)
x_subtrain6, x_valid6, y_subtrain6, y_valid6 = train_test_split(train_X, train_y, test_size=0.16, random_state=6)
x_subtrain7, x_valid7, y_subtrain7, y_valid7 = train_test_split(train_X, train_y, test_size=0.16, random_state=7)
x_subtrain8, x_valid8, y_subtrain8, y_valid8 = train_test_split(train_X, train_y, test_size=0.16, random_state=8)
x_subtrain9, x_valid9, y_subtrain9, y_valid9 = train_test_split(train_X, train_y, test_size=0.16, random_state=9)
x_subtrain10, x_valid10, y_subtrain10, y_valid10 = train_test_split(train_X, train_y, test_size=0.16, random_state=10)

# %% [markdown]
# #AdaGrad Optimizer

# %%
from keras.layers import Dense
from tensorflow.keras.optimizers import Adagrad
import tensorflow as tf
tf.keras.optimizers.Adagrad(learning_rate=0.02,initial_accumulator_value=0.4, epsilon=1e-08, name="Adagrad")

model = Sequential()
model.add(Dense(32, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(n_labels))
model.add(Activation('softmax'))

model.compile(optimizer='Adagrad', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(x_subtrain10, y_subtrain10, epochs=60, batch_size=64)
# Out:
# Epoch 1/60
# 788/788 [==============================] - 5s 5ms/step - loss: 1.9174 - accuracy: 0.3840
# Epoch 2/60
# 788/788 [==============================] - 4s 5ms/step - loss: 1.3933 - accuracy: 0.6062
# Epoch 3/60
# 788/788 [==============================] - 3s 4ms/step - loss: 1.1710 - accuracy: 0.6692
# Epoch 4/60
# 788/788 [==============================] - 2s 3ms/step - loss: 1.0411 - accuracy: 0.7040
# Epoch 5/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.9639 - accuracy: 0.7242
# Epoch 6/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.9079 - accuracy: 0.7410
# Epoch 7/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.8601 - accuracy: 0.7561
# Epoch 8/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.8289 - accuracy: 0.7627
# Epoch 9/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.8006 - accuracy: 0.7683
# Epoch 10/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.7761 - accuracy: 0.7761
# Epoch 11/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.7560 - accuracy: 0.7819
# Epoch 12/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.7362 - accuracy: 0.7870
# Epoch 13/60
# 788/788 [==============================] - 3s 4ms/step - loss: 0.7225 - accuracy: 0.7929
# Epoch 14/60
# 788/788 [==============================] - 3s 3ms/step - loss: 0.7084 - accuracy: 0.7936
# Epoch 15/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6982 - accuracy: 0.7987
# Epoch 16/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6875 - accuracy: 0.8012
# Epoch 17/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6749 - accuracy: 0.8031
# Epoch 18/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6668 - accuracy: 0.8083
# Epoch 19/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6556 - accuracy: 0.8090
# Epoch 20/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6523 - accuracy: 0.8106
# Epoch 21/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6426 - accuracy: 0.8128
# Epoch 22/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6315 - accuracy: 0.8179
# Epoch 23/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6249 - accuracy: 0.8181
# Epoch 24/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6214 - accuracy: 0.8199
# Epoch 25/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6175 - accuracy: 0.8189
# Epoch 26/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6125 - accuracy: 0.8201
# Epoch 27/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6069 - accuracy: 0.8237
# Epoch 28/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.6031 - accuracy: 0.8252
# Epoch 29/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5955 - accuracy: 0.8265
# Epoch 30/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5961 - accuracy: 0.8246
# Epoch 31/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5911 - accuracy: 0.8254
# Epoch 32/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5865 - accuracy: 0.8279
# Epoch 33/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5848 - accuracy: 0.8290
# Epoch 34/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5791 - accuracy: 0.8308
# Epoch 35/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5745 - accuracy: 0.8324
# Epoch 36/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5698 - accuracy: 0.8333
# Epoch 37/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5686 - accuracy: 0.8326
# Epoch 38/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5648 - accuracy: 0.8347
# Epoch 39/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5638 - accuracy: 0.8343
# Epoch 40/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.8358
# Epoch 41/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5558 - accuracy: 0.8393
# Epoch 42/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5559 - accuracy: 0.8366
# Epoch 43/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5541 - accuracy: 0.8397
# Epoch 44/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5496 - accuracy: 0.8391
# Epoch 45/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.8396
# Epoch 46/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.8414
# Epoch 47/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.8413
# Epoch 48/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5414 - accuracy: 0.8422
# Epoch 49/60
# 788/788 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.8429
# Epoch 50/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.8454
# Epoch 51/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.8424
# Epoch 52/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.8434
# Epoch 53/60
# 788/788 [==============================] - 3s 3ms/step - loss: 0.5281 - accuracy: 0.8460
# Epoch 54/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.8469
# Epoch 55/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5265 - accuracy: 0.8471
# Epoch 56/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5245 - accuracy: 0.8475
# Epoch 57/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5220 - accuracy: 0.8467
# Epoch 58/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5206 - accuracy: 0.8482
# Epoch 59/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5178 - accuracy: 0.8491
# Epoch 60/60
# 788/788 [==============================] - 2s 3ms/step - loss: 0.5157 - accuracy: 0.8503

# %%
train_acc = hist.history['accuracy']

# %%
avg_train = mean(train_acc)
print(avg_train*100)
# Out:
# 80.46240081389745

# %% [markdown]
# #Evaluation on Validation Set

# %%
_, accuracy = model.evaluate(x_valid10, y_valid10)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 300/300 [==============================] - 1s 2ms/step - loss: 0.3689 - accuracy: 0.8999
# Accuracy: 89.99

# %% [markdown]
# #Training with best Hyper-parameters -  ((0.001,0.4,1e-08))

# %%
tf.keras.optimizers.Adagrad(learning_rate=0.001,initial_accumulator_value=0.4, epsilon=1e-08, name="Adagrad")

model = Sequential()
model.add(Dense(32, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(n_labels))
model.add(Activation('softmax'))

model.compile(optimizer='Adagrad', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_X, train_y, epochs=60, batch_size=64)
# Out:
# Epoch 1/60
# 938/938 [==============================] - 3s 3ms/step - loss: 1.8798 - accuracy: 0.3739
# Epoch 2/60
# 938/938 [==============================] - 2s 3ms/step - loss: 1.3861 - accuracy: 0.5752
# Epoch 3/60
# 938/938 [==============================] - 2s 3ms/step - loss: 1.1897 - accuracy: 0.6388
# Epoch 4/60
# 938/938 [==============================] - 2s 2ms/step - loss: 1.0756 - accuracy: 0.6775
# Epoch 5/60
# 938/938 [==============================] - 2s 3ms/step - loss: 1.0006 - accuracy: 0.6998
# Epoch 6/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.9421 - accuracy: 0.7151
# Epoch 7/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.8991 - accuracy: 0.7293
# Epoch 8/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.8628 - accuracy: 0.7418
# Epoch 9/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.8361 - accuracy: 0.7496
# Epoch 10/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.8151 - accuracy: 0.7563
# Epoch 11/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.7934 - accuracy: 0.7624
# Epoch 12/60
# 938/938 [==============================] - 3s 4ms/step - loss: 0.7736 - accuracy: 0.7684
# Epoch 13/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.7577 - accuracy: 0.7717
# Epoch 14/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.7421 - accuracy: 0.7774
# Epoch 15/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.7283 - accuracy: 0.7807
# Epoch 16/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.7181 - accuracy: 0.7874
# Epoch 17/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.7059 - accuracy: 0.7870
# Epoch 18/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.6989 - accuracy: 0.7904
# Epoch 19/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6889 - accuracy: 0.7906
# Epoch 20/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6819 - accuracy: 0.7949
# Epoch 21/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6728 - accuracy: 0.7987
# Epoch 22/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6685 - accuracy: 0.7978
# Epoch 23/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6563 - accuracy: 0.8023
# Epoch 24/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6587 - accuracy: 0.8013
# Epoch 25/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.6483 - accuracy: 0.8043
# Epoch 26/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6449 - accuracy: 0.8087
# Epoch 27/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6407 - accuracy: 0.8095
# Epoch 28/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6387 - accuracy: 0.8079
# Epoch 29/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6290 - accuracy: 0.8101
# Epoch 30/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6259 - accuracy: 0.8128
# Epoch 31/60
# 938/938 [==============================] - 2s 2ms/step - loss: 0.6228 - accuracy: 0.8113
# Epoch 32/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6154 - accuracy: 0.8168
# Epoch 33/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6182 - accuracy: 0.8149
# Epoch 34/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6120 - accuracy: 0.8175
# Epoch 35/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6080 - accuracy: 0.8185
# Epoch 36/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.6065 - accuracy: 0.8188
# Epoch 37/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5979 - accuracy: 0.8216
# Epoch 38/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5992 - accuracy: 0.8205
# Epoch 39/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5955 - accuracy: 0.8219
# Epoch 40/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5942 - accuracy: 0.8225
# Epoch 41/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5910 - accuracy: 0.8216
# Epoch 42/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5902 - accuracy: 0.8227
# Epoch 43/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5820 - accuracy: 0.8260
# Epoch 44/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5830 - accuracy: 0.8266
# Epoch 45/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5787 - accuracy: 0.8268
# Epoch 46/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5771 - accuracy: 0.8275
# Epoch 47/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5754 - accuracy: 0.8277
# Epoch 48/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5722 - accuracy: 0.8287
# Epoch 49/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5736 - accuracy: 0.8268
# Epoch 50/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5714 - accuracy: 0.8293
# Epoch 51/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5682 - accuracy: 0.8303
# Epoch 52/60
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5675 - accuracy: 0.8298
# Epoch 53/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5629 - accuracy: 0.8334
# Epoch 54/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5630 - accuracy: 0.8315
# Epoch 55/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5602 - accuracy: 0.8342
# Epoch 56/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5603 - accuracy: 0.8327
# Epoch 57/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5573 - accuracy: 0.8351
# Epoch 58/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5541 - accuracy: 0.8346
# Epoch 59/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5526 - accuracy: 0.8344
# Epoch 60/60
# 938/938 [==============================] - 2s 3ms/step - loss: 0.5520 - accuracy: 0.8336

# %%
model.evaluate(test_X, test_y)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3483 - accuracy: 0.9084
# [0.34833285212516785, 0.9083999991416931]
